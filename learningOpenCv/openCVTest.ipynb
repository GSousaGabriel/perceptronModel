# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img= cv2.imread('./ACARMANBOSS.jpg')

# %%
plt.imshow(img)

# %%
imgfixed= cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imgfixed)

# %%
imgGray= cv2.imread('./ACARMANBOSS.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(imgGray, cmap='gray')

# %%
w_ratio = 0.2
h_ratio = 0.2

# %%
new_img= cv2.resize(imgfixed, (0,0), imgfixed, w_ratio, h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (17, 12, 3)

# %%
flipped_img = cv2.flip(imgfixed, 180)

# %%
plt.imshow(flipped_img)

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.imshow(imgfixed)
