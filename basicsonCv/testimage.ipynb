# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('./ACARMANBOSS.jpg')
print(type(pic))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
pic_arr= np.asarray(pic)

# %%
pic_arr.shape
# Out:
# (85, 60, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red= pic_arr.copy()

# %%
pic_red.shape
# Out:
# (85, 60, 3)

# %%
# plt.imshow(pic_red[:,:,1], cmap= 'gray')
pic_red[:,:,1]= 0
pic_red[:,:,2]= 0

# %%
plt.imshow(pic_red)
